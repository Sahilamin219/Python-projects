# %%
# Number of colors/ shades = 2^bpp where bpp represents bits per pixel.
#import the necessary libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
#reading image
img_raw = cv2.imread('/home/sahil/Documents/images.jpeg')
#type and shape of the array
type(img_raw)
np.ndarray
img_raw.shape
#viewing the image
plt.imshow(img_raw)
#transforming the channel
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
plt.imshow(img_raw)

# %%
# using python Scripts
# jupyter notebooks are not great in dealing with complex images 
# so in this section we will be executing the code as .py file 
# write in sublime
import cv2
img = cv2.imread('images.jpeg')
while(True):
    cv2.imshow('images',img)
    if cv2.waitkey(1) & 0xFF == 27:
        break
        
cv2.destroyAllWindows()
# saving images
cv2.imwrite('final_image.jpeg', img)
#where final_image is the name of the image to be stored
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-d6a3e52a04f7> in <module>
#       6 img = cv2.imread('images.jpeg')
#       7 while(True):
# ----> 8     cv2.imshow('images',img)
#       9     if cv2.waitkey(1) & 0xFF == 27:
#      10         break
#
# error: OpenCV(4.1.1) /io/opencv/modules/highgui/src/window.cpp:352: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
image_blank = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(image_blank)

# %%
# cv2.shape(line, rectangle etc)(image,Pt1,Pt2,color,thickness)
# Image on which shapes are to be drawn
# co-ordinates of the shape to be drawn from Pt1(top left) to Pt2(bottom right)
# Color: The color of the shape that is to be drawn. It is passed as a tuple, eg: (255,0,0). For grayscale, it will be the scale of brightness.
# The thickness of the geometrical figure.
line_red = cv2.line(image_blank,(0,0),(511,511),(255,0,0),5)
plt.imshow(line_red)
rectangle= cv2.rectangle(image_blank,(384,0),(510,128),(0,0,255),5)
plt.imshow(rectangle)

# %%
line_red = cv2.line(image_blank,(0,0),(511,511),(255,0,0),5)
plt.imshow(line_red)
rectangle= cv2.rectangle(image_blank,(384,0),(510,128),(0,0,255),5)
plt.imshow(rectangle)
img = cv2.circle(img,(447,63), 63, (0,0,255), -1) # -1 corresponds to a filled circle
plt.imshow(circle)

# %%
y = np.arange(3, dtype=float)
print(y)
np.zeros_like(y)
# Out:
# [0. 1. 2.]
# array([0., 0., 0.])

# %%
# Text to be written
# coordinates of the text. The text on an image begins from the bottom left direction.
# Font type and scale.
# Other attributes like color, thickness and line type. Normally the line type that is used is lineType = cv2.LINE_AA.
image = np.zeros((512,512,3),dtype=np.int16)
img = cv2.rectangle(image,(0,0),(511,511),(255,0,0),5)
plt.imshow(img)
font = cv2.FONT_HERSHEY_SIMPLEX
text = cv2.putText(img,'OpenCV',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
plt.imshow(text)
